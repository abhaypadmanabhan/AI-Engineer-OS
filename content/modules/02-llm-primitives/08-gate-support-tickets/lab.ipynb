# %% [markdown]
# # Lab 08 — Layer 2 gate: ticket classifier
# Classify 55 labeled tickets into 12 categories. Target accuracy >= 0.88.
# Cost math (55 tickets): per call ~450 input + ~20 output on claude-sonnet-4-6.
# input = 55*450 = 24,750 tok -> (24750/1e6)*3 = $0.0743
# output = 55*20 = 1,100 tok -> (1100/1e6)*15 = $0.0165
# total ~ $0.09 for 55 tickets; ~$0.33 for a 200-ticket full run.

# %%
# !uv add anthropic pydantic

# %%
from solution import run_eval
acc = run_eval()
print('PASS' if acc >= 0.88 else 'FAIL', f'(acc={acc:.3f})')
